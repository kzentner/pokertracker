# %%
from PreflopHand import PreflopHand
import ipywidgets as widgets
from IPython.display import display

class Grid:
    def __init__(self):
        cardTypes = ['A', 'K', 'Q', 'J', 'T', '9', '8', '7', '6', '5', '4', '3', '2']
        i = 0
        rows = []
        layout = widgets.Layout(display="flex")
        while i < len(cardTypes):
            j = 0
            children = []
            while j < len(cardTypes):
                cardStr = ""
                if i > j:
                    cardStr = cardTypes[j] + cardTypes[i] + 'o'
                elif i < j:
                    cardStr = cardTypes[i] + cardTypes[j] + 's'
                else:
                    cardStr = cardTypes[i] + cardTypes[j]

                children.append(PreflopHand(cardStr).get_display())
                j += 1
            rows.append(widgets.HBox(children=children, layout=widgets.Layout(display="flex")))
            i += 1

        self.grid = widgets.Box(
            children=[rows],
            layout=widgets.Layout(
                display="flex",
                flex_flow="column",
                align_items="flex-start"
            )
        )
        self.grid.align_items="flex_start"

display(Grid().grid)
# Out:
# ---------------------------------------------------------------------------
# TraitError                                Traceback (most recent call last)
# Cell In [7], line 38
#      28         self.grid = widgets.Box(
#      29             children=[rows],
#      30             layout=widgets.Layout(
#    (...)
#      34             )
#      35         )
#      36         self.grid.align_items="flex_start"
# ---> 38 display(Grid().grid)
#
# Cell In [7], line 25, in Grid.__init__(self)
#      23         children.append(PreflopHand(cardStr).get_display())
#      24         j += 1
# ---> 25     rows.append(widgets.HBox(children=[children], layout=widgets.Layout(display="flex")))
#      26     i += 1
#      28 self.grid = widgets.Box(
#      29     children=[rows],
#      30     layout=widgets.Layout(
#    (...)
#      34     )
#      35 )
#
# File /mnt/c/users/zentn/projects/poker/env/lib/python3.8/site-packages/ipywidgets/widgets/widget_box.py:64, in Box.__init__(self, children, **kwargs)
#      62 def __init__(self, children=(), **kwargs):
#      63     kwargs['children'] = children
# ---> 64     super().__init__(**kwargs)
#
# File /mnt/c/users/zentn/projects/poker/env/lib/python3.8/site-packages/ipywidgets/widgets/widget.py:443, in Widget.__init__(self, **kwargs)
#     441 """Public constructor"""
#     442 self._model_id = kwargs.pop('model_id', None)
# --> 443 super().__init__(**kwargs)
#     445 Widget._call_widget_constructed(self)
#     446 self.open()
#
# File /mnt/c/users/zentn/projects/poker/env/lib/python3.8/site-packages/traitlets/traitlets.py:1235, in HasTraits.__init__(self, *args, **kwargs)
#    1233 for key, value in kwargs.items():
#    1234     if self.has_trait(key):
# -> 1235         setattr(self, key, value)
#    1236     else:
#    1237         # passthrough args that don't set traits to super
#    1238         super_kwargs[key] = value
#
# File /mnt/c/users/zentn/projects/poker/env/lib/python3.8/site-packages/traitlets/traitlets.py:715, in TraitType.__set__(self, obj, value)
#     713     raise TraitError('The "%s" trait is read-only.' % self.name)
#     714 else:
# --> 715     self.set(obj, value)
#
# File /mnt/c/users/zentn/projects/poker/env/lib/python3.8/site-packages/traitlets/traitlets.py:689, in TraitType.set(self, obj, value)
#     688 def set(self, obj, value):
# --> 689     new_value = self._validate(obj, value)
#     690     try:
#     691         old_value = obj._trait_values[self.name]
#
# File /mnt/c/users/zentn/projects/poker/env/lib/python3.8/site-packages/traitlets/traitlets.py:721, in TraitType._validate(self, obj, value)
#     719     return value
#     720 if hasattr(self, "validate"):
# --> 721     value = self.validate(obj, value)  # type:ignore[attr-defined]
#     722 if obj._cross_validation_lock is False:
#     723     value = self._cross_validate(obj, value)
#
# File /mnt/c/users/zentn/projects/poker/env/lib/python3.8/site-packages/traitlets/traitlets.py:2695, in Container.validate(self, obj, value)
#    2692 if value is None:
#    2693     return value
# -> 2695 value = self.validate_elements(obj, value)
#    2697 return value
#
# File /mnt/c/users/zentn/projects/poker/env/lib/python3.8/site-packages/traitlets/traitlets.py:2707, in Container.validate_elements(self, obj, value)
#    2705     v = self._trait._validate(obj, v)
#    2706 except TraitError as error:
# -> 2707     self.error(obj, v, error)
#    2708 else:
#    2709     validated.append(v)
#
# File /mnt/c/users/zentn/projects/poker/env/lib/python3.8/site-packages/traitlets/traitlets.py:806, in TraitType.error(self, obj, value, error, info)
#     795         else:
#     796             error.args = (
#     797                 "The '%s' trait contains %s which "
#     798                 "expected %s, not %s."
#    (...)
#     804                 ),
#     805             )
# --> 806     raise error
#     807 else:
#     808     # this trait caused an error
#     809     if self.name is None:
#     810         # this is not the root trait
#
# File /mnt/c/users/zentn/projects/poker/env/lib/python3.8/site-packages/traitlets/traitlets.py:2705, in Container.validate_elements(self, obj, value)
#    2703 for v in value:
#    2704     try:
# -> 2705         v = self._trait._validate(obj, v)
#    2706     except TraitError as error:
#    2707         self.error(obj, v, error)
#
# File /mnt/c/users/zentn/projects/poker/env/lib/python3.8/site-packages/traitlets/traitlets.py:721, in TraitType._validate(self, obj, value)
#     719     return value
#     720 if hasattr(self, "validate"):
# --> 721     value = self.validate(obj, value)  # type:ignore[attr-defined]
#     722 if obj._cross_validation_lock is False:
#     723     value = self._cross_validate(obj, value)
#
# File /mnt/c/users/zentn/projects/poker/env/lib/python3.8/site-packages/traitlets/traitlets.py:2032, in Instance.validate(self, obj, value)
#    2030     return value
#    2031 else:
# -> 2032     self.error(obj, value)
#
# File /mnt/c/users/zentn/projects/poker/env/lib/python3.8/site-packages/traitlets/traitlets.py:811, in TraitType.error(self, obj, value, error, info)
#     807 else:
#     808     # this trait caused an error
#     809     if self.name is None:
#     810         # this is not the root trait
# --> 811         raise TraitError(value, info or self.info(), self)
#     812     else:
#     813         # this is the root trait
#     814         if obj is not None:
#
# TraitError: The 'children' trait of a HBox instance contains an Instance of a TypedTuple which expected a Widget, not the list [HTML(value='<style>\n            h3 {\n                border: 1px solid black;\n                height: 55px;\n                width: 55px;\n                display: flex;\n                align-items: center;\n                justify-content: center;\n            }\n            </style>\n            <h3>AA</h3>\n        '), HTML(value='<style>\n            h3 {\n                border: 1px solid black;\n                height: 55px;\n                width: 55px;\n                display: flex;\n                align-items: center;\n                justify-content: center;\n            }\n            </style>\n            <h3>AKs</h3>\n        '), HTML(value='<style>\n            h3 {\n                border: 1px solid black;\n                height: 55px;\n                width: 55px;\n                display: flex;\n                align-items: center;\n                justify-content: center;\n            }\n            </style>\n            <h3>AQs</h3>\n        '), HTML(value='<style>\n            h3 {\n                border: 1px solid black;\n                height: 55px;\n                width: 55px;\n                display: flex;\n                align-items: center;\n                justify-content: center;\n            }\n            </style>\n            <h3>AJs</h3>\n        '), HTML(value='<style>\n            h3 {\n                border: 1px solid black;\n                height: 55px;\n                width: 55px;\n                display: flex;\n                align-items: center;\n                justify-content: center;\n            }\n            </style>\n            <h3>ATs</h3>\n        '), HTML(value='<style>\n            h3 {\n                border: 1px solid black;\n                height: 55px;\n                width: 55px;\n                display: flex;\n                align-items: center;\n                justify-content: center;\n            }\n            </style>\n            <h3>A9s</h3>\n        '), HTML(value='<style>\n            h3 {\n                border: 1px solid black;\n                height: 55px;\n                width: 55px;\n                display: flex;\n                align-items: center;\n                justify-content: center;\n            }\n            </style>\n            <h3>A8s</h3>\n        '), HTML(value='<style>\n            h3 {\n                border: 1px solid black;\n                height: 55px;\n                width: 55px;\n                display: flex;\n                align-items: center;\n                justify-content: center;\n            }\n            </style>\n            <h3>A7s</h3>\n        '), HTML(value='<style>\n            h3 {\n                border: 1px solid black;\n                height: 55px;\n                width: 55px;\n                display: flex;\n                align-items: center;\n                justify-content: center;\n            }\n            </style>\n            <h3>A6s</h3>\n        '), HTML(value='<style>\n            h3 {\n                border: 1px solid black;\n                height: 55px;\n                width: 55px;\n                display: flex;\n                align-items: center;\n                justify-content: center;\n            }\n            </style>\n            <h3>A5s</h3>\n        '), HTML(value='<style>\n            h3 {\n                border: 1px solid black;\n                height: 55px;\n                width: 55px;\n                display: flex;\n                align-items: center;\n                justify-content: center;\n            }\n            </style>\n            <h3>A4s</h3>\n        '), HTML(value='<style>\n            h3 {\n                border: 1px solid black;\n                height: 55px;\n                width: 55px;\n                display: flex;\n                align-items: center;\n                justify-content: center;\n ...
